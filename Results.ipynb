# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme()

# %% [markdown]
# # Systematic literature review

# %%
slr = pd.read_excel("SLR.xlsx")

# %%
categories = slr["Category"].value_counts()
categories
# Out:
# Applications    23
# Implications    20
# Both             7
# Name: Category, dtype: int64

# %%
slr["Topic"].value_counts()#.to_excel("topics.xlsx")
# Out:
# Overview                        6
# Fintech                         4
# Digital assets                  4
# Intellectual property           3
# Standardization                 3
# NFT markets                     3
# Tracking                        3
# Digital economy                 3
# Collectibles                    3
# Collections                     2
# Asset management                2
# Creative industries             2
# Racism                          1
# Tourism/hospitality             1
# Ticketing                       1
# Sports                          1
# Smart contracts                 1
# Encryption solutions            1
# Privacy laws                    1
# Energy tokenization             1
# Marketing                       1
# Imaging                         1
# Environmental sustainability    1
# Art generation                  1
# Name: Topic, dtype: int64

# %%
sentiment = slr["Sentiment"].value_counts()
sentiment
# Out:
# Positive    37
# Neutral      8
# Negative     5
# Name: Sentiment, dtype: int64

# %%
slr.groupby(["Category", "Topic"])["Topic"].count()#.to_excel("categories_topics.xlsx")
# Out:
# Category      Topic
# Applications  Art generation                  1
#               Asset management                2
#               Collectibles                    1
#               Collections                     2
#               Digital assets                  1
#               Encryption solutions            1
#               Energy tokenization             1
#               Fintech                         3
#               Intellectual property           1
#               Overview                        3
#               Smart contracts                 1
#               Standardization                 2
#               Ticketing                       1
#               Tracking                        3
# Both          Collectibles                    1
#               Creative industries             1
#               Digital assets                  1
#               Overview                        2
#               Privacy laws                    1
# ...

# %%
slr.groupby(["Topic", "Sentiment"])["Sentiment"].count()#.to_excel("topics_sentiment.xlsx")
# Out:
# Topic                         Sentiment
# Art generation                Positive     1
# Asset management              Neutral      1
#                               Positive     1
# Collectibles                  Negative     1
#                               Neutral      1
#                               Positive     1
# Collections                   Positive     2
# Creative industries           Positive     2
# Digital assets                Negative     1
#                               Neutral      1
#                               Positive     2
# Digital economy               Neutral      1
#                               Positive     2
# Encryption solutions          Positive     1
# Energy tokenization           Positive     1
# Environmental sustainability  Negative     1
# Fintech                       Neutral      1
#                               Positive     3
# Imaging                       Positive     1
# Intellectual property         Positive     3
# ...

# %%
plt.figure(figsize=(7,4))

# create data
x = np.arange(1)
y1 = [23]
y2 = [20]
y3 = [7]
y4 = [0]
width = 0.01

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.01, y1, width, color="tab:blue")
plt.bar_label(bar1, padding=2, fontsize=13)
bar2 = plt.barh(x, y2, width, color="tab:green")
plt.bar_label(bar2, padding=2, fontsize=13)
bar3 = plt.barh(x-0.01, y3, width, color="tab:orange")
plt.bar_label(bar3, padding=2, fontsize=13)

plt.xlim(0, 50)
plt.xticks([0, 50], fontsize=14)
plt.yticks(x, ["Overall"], fontsize=14)
plt.xlabel("Frequency", fontsize=14)
plt.legend(["Application", "Implication", "Both"], fontsize=13)
plt.savefig("slrtypes.png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# # Sentiment analysis

# %%
q1s = pd.read_excel("q1s_excel.xlsx")
q4s = pd.read_excel("q4s_excel.xlsx")
# Out:
# C:\Users\Robin\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# ## Q1S + Q4S

# %%
#q1s + q4s
plt.figure(figsize=(7,5))

# create data
x = np.arange(3)
y1 = [141, 38, 179]
y2 = [4, 25, 29]
y3 = [1, 4, 5]
y4 = [5, 8, 13]
width = 0.2

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.3, y1, width, color="tab:blue")
plt.bar_label(bar1, padding=2, fontsize=13)
bar2 = plt.barh(x+0.1, y2, width, color="tab:green")
plt.bar_label(bar2, padding=2, fontsize=13)
bar3 = plt.barh(x-0.1, y3, width, color="tab:orange")
plt.bar_label(bar3, padding=2, fontsize=13)
bar4 = plt.barh(x-0.3, y4, width, color="tab:gray")
plt.bar_label(bar4, padding=2, fontsize=13)

plt.xlim(0, 226)
plt.xticks([0, 226], fontsize=14)
plt.yticks(x, ["Promotion", "Non-promotion", "Overall"], fontsize=14)
plt.xlabel("Frequency", fontsize=14)
plt.legend(["Application", "Implication", "Both", "Other"], fontsize=13)
plt.savefig("q1sq4stypes.png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## Q1S

# %%
q1scat = q1s["category"].value_counts()
q1scat
# Out:
# a    83
# i    22
# o     8
# Name: category, dtype: int64

# %%
q1s["topic"].value_counts()#.to_excel("topics_q1s.xlsx")
# Out:
# creative industries      62
# practical question       24
# metadiscussion           13
# nft platform              4
# discord community         2
# collaboration request     2
# web domain                1
# security breach           1
# blogpost                  1
# fraud                     1
# nft game(s)               1
# waste management          1
# Name: topic, dtype: int64

# %%
q1s["promotion"].value_counts()
# Out:
# y    68
# n    45
# Name: promotion, dtype: int64

# %%
q1s.groupby(["topic", "promotion"])["promotion"].count()#.to_excel("topics_promotion_q1s.xlsx")
# Out:
# topic                  promotion
# blogpost               y             1
# collaboration request  y             2
# creative industries    n             5
#                        y            57
# discord community      y             2
# fraud                  n             1
# metadiscussion         n            13
# nft game(s)            y             1
# nft platform           y             4
# practical question     n            24
# security breach        n             1
# waste management       n             1
# web domain             y             1
# Name: promotion, dtype: int64

# %%
q1s.groupby(["category", "promotion"])["promotion"].count()
# Out:
# category  promotion
# a         n            22
#           y            61
# i         n            19
#           y             3
# o         n             4
#           y             4
# Name: promotion, dtype: int64

# %%
#q1s
plt.figure(figsize=(7,5))

# create data
x = np.arange(3)
y1 = [61, 22, 83]
y2 = [3, 19, 22]
y3 = [0, 0, 0]
y4 = [4, 4, 8]
width = 0.2

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.3, y1, width, color="tab:blue")
plt.bar_label(bar1, padding=2, fontsize=13)
bar2 = plt.barh(x+0.1, y2, width, color="tab:green")
plt.bar_label(bar2, padding=2, fontsize=13)
bar3 = plt.barh(x-0.1, y3, width, color="tab:orange")
plt.bar_label(bar3, padding=2, fontsize=13)
bar4 = plt.barh(x-0.3, y4, width, color="tab:gray")
plt.bar_label(bar4, padding=2, fontsize=13)

plt.xlim(0, 113)
plt.xticks([0, 113], fontsize=14)
plt.yticks(x, ["Promotion", "Non-promotion", "Overall"], fontsize=14)
plt.xlabel("Frequency", fontsize=14)
plt.legend(["Application", "Implication", "Both", "Other"], fontsize=13)
plt.savefig("q1stypes.png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## Q4S

# %%
q4scat = q4s["category"].value_counts()
q4scat
# Out:
# a    96
# i     7
# o     5
# b     5
# Name: category, dtype: int64

# %%
q4s["topic"].value_counts()#.to_excel("topics_q4s.xlsx")
# Out:
# creative industries      62
# practical question       15
# metadiscussion            9
# nft game(s)               7
# nft platform              5
# collaboration request     4
# digital assets            2
# video                     1
# scam                      1
# hospitality               1
# animal video footage      1
# gaming                    1
# clothing                  1
# contest                   1
# community                 1
# beggar                    1
# Name: topic, dtype: int64

# %%
q4s["promotion"].value_counts()
# Out:
# y    83
# n    30
# Name: promotion, dtype: int64

# %%
q4s.groupby(["topic", "promotion"])["promotion"].count()#.to_excel("topics_promotion_q4s.xlsx")
# Out:
# topic                  promotion
# animal video footage   y             1
# beggar                 y             1
# clothing               y             1
# collaboration request  y             4
# community              y             1
# contest                y             1
# creative industries    n             1
#                        y            61
# digital assets         n             1
#                        y             1
# gaming                 n             1
# hospitality            n             1
# metadiscussion         n             9
# nft game(s)            n             1
#                        y             6
# nft platform           y             5
# practical question     n            15
# scam                   n             1
# video                  y             1
# Name: promotion, dtype: int64

# %%
q4s.groupby(["category", "promotion"])["promotion"].count()
# Out:
# category  promotion
# a         n            16
#           y            80
# b         n             4
#           y             1
# i         n             6
#           y             1
# o         n             4
#           y             1
# Name: promotion, dtype: int64

# %%
#q4s
plt.figure(figsize=(7,5))

# create data
x = np.arange(3)
y1 = [80, 16, 96]
y2 = [1, 6, 7]
y3 = [1, 4, 5]
y4 = [1, 4, 5]
width = 0.2

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.3, y1, width, color="tab:blue")
plt.bar_label(bar1, padding=2, fontsize=13)
bar2 = plt.barh(x+0.1, y2, width, color="tab:green")
plt.bar_label(bar2, padding=2, fontsize=13)
bar3 = plt.barh(x-0.1, y3, width, color="tab:orange")
plt.bar_label(bar3, padding=2, fontsize=13)
bar4 = plt.barh(x-0.3, y4, width, color="tab:gray")
plt.bar_label(bar4, padding=2, fontsize=13)

plt.xlim(0, 113)
plt.xticks([0, 113], fontsize=14)
plt.yticks(x, ["Promotion", "Non-promotion", "Overall"], fontsize=14)
plt.xlabel("Frequency", fontsize=14)
plt.legend(["Application", "Implication", "Both", "Other"], fontsize=13)
plt.savefig("q4stypes.png", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## Overall results

# %%
#Sentiment
plt.figure(figsize=(7,5))

# create data
x = np.arange(2)
y1 = [12.7, 10]
y2 = [0.7, 16]
y3 = [86.5, 74]
width = 0.2

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.2, y1, width, color="tab:red")
plt.bar_label(bar1, padding=2, fontsize=13, fmt='%.1f%%')
bar2 = plt.barh(x, y2, width, color="tab:orange")
plt.bar_label(bar2, padding=2, fontsize=13, fmt='%.1f%%')
bar3 = plt.barh(x-0.2, y3, width, color="tab:green")
plt.bar_label(bar3, padding=2, fontsize=13, fmt='%.1f%%')

plt.xlim(0, 100)
plt.xticks([0, 100], fontsize=14)
plt.yticks(x, ["Early adopters", "Academics"], fontsize=14)
plt.xlabel("Percentage", fontsize=14)
plt.legend(["Negative", "Neutral", "Positive"], fontsize=13)
plt.savefig("overallsentiment.png", bbox_inches="tight", dpi=300)
plt.show()

# %%
#NFT types
plt.figure(figsize=(7,5))

# create data
x = np.arange(2)
y1 = [50.7, 46]
y2 = [33.3, 40]
y3 = [5.3, 14]
y4 = [10.7, 0]
width = 0.2

# plot data in grouped manner of bar type
bar1 = plt.barh(x+0.3, y1, width, color="tab:blue")
plt.bar_label(bar1, padding=2, fontsize=13, fmt='%.1f%%')
bar2 = plt.barh(x+0.1, y2, width, color="tab:green")
plt.bar_label(bar2, padding=2, fontsize=13, fmt='%.1f%%')
bar3 = plt.barh(x-0.1, y3, width, color="tab:orange")
plt.bar_label(bar3, padding=2, fontsize=13, fmt='%.1f%%')
bar4 = plt.barh(x-0.3, y4, width, color="tab:gray")
plt.bar_label(bar4, padding=2, fontsize=13, fmt='%.1f%%')

plt.xlim(0, 100)
plt.xticks([0, 100], fontsize=14)
plt.yticks(x, ["Early adopters", "Academics"], fontsize=14)
plt.xlabel("Percentage", fontsize=14)
plt.legend(["Application", "Implication", "Both", "Other"], fontsize=13)
plt.savefig("overalltypes.png", bbox_inches="tight", dpi=300)
plt.show()
